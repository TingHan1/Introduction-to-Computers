# %% [markdown]
# <a href="https://colab.research.google.com/github/TingHan1/Introduction-to-Computers/blob/main/0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hi')
# Out:
# Hi

# %%
not(3>5)
# Out:
# True

# %% [markdown]
# ![螢幕擷取畫面 2022-03-30 195753.png](data:image/png;base64,...)

# %%
not(8>6)
# Out:
# False

# %%
not(6>8)
# Out:
# True

# %%
(8>6)and(4>1)
# Out:
# True

# %%
(8>6)and(1>4)
# Out:
# False

# %%
(6>8)and(4>1)
# Out:
# False

# %%
(6>8)and(1>4)
# Out:
# False

# %%
(8>6)or(4>1)
# Out:
# True

# %%
(8>6)or(1>4)
# Out:
# True

# %%
(6>8)or(4>1)
# Out:
# True

# %%
(6>8)or(1>4)
# Out:
# False

# %%
A=1

# %%
i=10

# %%
i += 5

# %%
i
# Out:
# 15

# %%
i -=5
i
# Out:
# 10

# %%
i=10

# %%
i-=5
i
# Out:
# 5

# %%
i=10
i*=5
i
# Out:
# 50

# %%
print(1+2)
# Out:
# 3

# %%
print('1'+'2')
# Out:
# 12

# %%
print('你'+'好'+'!')
# Out:
# 你好!

# %%
deposit= int(input('請輸入本金存款金額:'))
years = 1.02**6
deposit *= years
print('6年後存款為:', deposit)
# Out:
# 請輸入本金存款金額:10000
# 6年後存款為: 11261.62419264

# %%
deposit= int(input('請輸入本金存款金額:'))
years = 1.02**6
deposit *= years
print('6年後存款為:'+str(deposit))
# Out:
# 請輸入本金存款金額:10000
# 6年後存款為:11261.62419264

# %%
pw = input('請輸入密碼')
if (pw == '1234'):
  print('歡迎光臨!')
# Out:
# 請輸入密碼1234
# 歡迎光臨!

# %% [markdown]
# 請輸入密碼11111

# %%
rain = input("今天會下雨嗎?")
if(rain=="Y" or rain=="y"):
  print("出門記得帶傘!")
# Out:
# 今天會下雨嗎?y
# 出門記得帶傘!

# %%
rain = input("今天會下雨嗎?")
if(rain=="Y" or rain=="y"):
  print("出門記得帶傘!")
else:
  print('不用帶傘')
# Out:
# 今天會下雨嗎?2
# 不用帶傘

# %%
a= int(input('請輸入正整數:'))
if a%2 == 0:
  print("a為偶數!")
else:
  print("a為奇數!")
# Out:
# 請輸入正整數:50
# a為偶數!
